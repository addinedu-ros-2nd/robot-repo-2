# %%
from ultralytics import YOLO
import cv2

from ultralytics.utils import ASSETS
from ultralytics.models.yolo.pose import PosePredictor


# model = YOLO("yolo8s.pt")
model = YOLO("yolov8n-pose.pt")

# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture("/home/seokwon/Desktop/RNN_data/2023-11-10_11-23-06.avi") #  보는 시점 기준 정중앙에 서있음
# cap = cv2.VideoCapture("/home/seokwon/Desktop/RNN_data/2023-11-10_11-23-00.avi") # 보는 시점 기준 오른쪽에 서있음





while cap.isOpened() :
    ret, frame = cap.read()

    if ret :
        results = model(frame)
        for result in results:
            for keypoints in result.keypoints:
                xyn = keypoints.xyn
                # print("Keypoints [5] :", xyn[5])
                # print("Keypoints [11] :", xyn[11])
                # print("Keypoints [13] :", xyn[13])
                selected_keypoints = xyn[0, [5, 11, 13], :]
                # shoulder = xyn[0, [5], :]
                # hip = xyn[0, [11], :]
                # knee = xyn[0, [13], :]
                print("Keypoints 어깨, 골반, 무릎:", selected_keypoints)


        cv2.imshow("Results", results[0].plot()) 

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 480x640 1 person, 8.6ms
# Speed: 6.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Keypoints 어깨, 골반, 무릎: tensor([[0.5608, 0.1462],
#         [0.5041, 0.4125],
#         [0.4800, 0.6662]], device='cuda:0')
# 0: 480x640 1 person, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5.8ms
# Speed: 4.0ms preprocess, 5.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Keypoints 어깨, 골반, 무릎: tensor([[0.5585, 0.1511],
#         [0.5014, 0.4251],
#         [0.4883, 0.6701]], device='cuda:0')
# Keypoints 어깨, 골반, 무릎: tensor([[0.5589, 0.1493],
#         [0.5019, 0.4224],
#         [0.4880, 0.6687]], device='cuda:0')
# Keypoints 어깨, 골반, 무릎: tensor([[0.5585, 0.1504],
#         [0.5020, 0.4223],
#         [0.4877, 0.6677]], device='cuda:0')
# Keypoints 어깨, 골반, 무릎: tensor([[0.5583, 0.1516],
#         [0.5024, 0.4220],
#         [0.4883, 0.6673]], device='cuda:0')
# Keypoints 어깨, 골반, 무릎: tensor([[0.5585, 0.1573],
#         [0.5031, 0.4240],
#         [0.4894, 0.6671]], device='cuda:0')
# Keypoints 어깨, 골반, 무릎: tensor([[0.5592, 0.1551],
#         [0.5028, 0.4237],
#         [0.4890, 0.6675]], device='cuda:0')

# %%
import numpy as np


###
# yolov8-pose skeleton keypoint
# 0: 'nose',
# 1: 'left_eye',
# 2: 'right_eye',
# 3: 'left_ear',
# 4: 'right_ear',
# 5: 'left_shoulder',    
# 6: 'right_shoulder',    
# 7: 'left_elbow',
# 8: 'right_elbow',
# 9: 'left_wrist',
# 10: 'right_wrist',
# 11: 'left_hip',
# 12: 'right_hip',
# 13: 'left_knee',
# 14: 'right_knee',
# 15: 'left_ankle',
# 16: 'right_ankle'
###
def calculate_angle(joint1, joint2, joint3): 
    # 어깨 골반 무릎 순서
    # 하지만 사실 점 3개를 해도 된다
    # 5,6 어깨
    # 11, 12 골반
    # 13, 14 무릎
    

    vector1 = np.array(joint1) - np.array(joint2)
    vector2 = np.array(joint3) - np.array(joint2)

    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)

    cosine_theta = dot_product / (magnitude1 * magnitude2)
    angle = np.arccos(np.clip(cosine_theta, -1.0, 1.0))

    return np.degrees(angle)

# 예시 키포인트 값
pelvis = [0.5, 0.5]  # 골반
shoulder = [0.5, 0.6]  # 어깨
knee = [0.5, 0.4]  # 무릎

# 어깨, 골반, 무릎으로 이루어진 각을 계산
angle = calculate_angle(shoulder, pelvis, knee)

# 각이 특정 값보다 작으면 앉은 상태로 간주
threshold_angle = 90  # 예시값. 실제로는 실험을 통해 적절한 값을 찾아야 합니다.

if angle < threshold_angle:
    print("앉은 상태입니다.")
else:
    print("서 있는 상태입니다.")
# Out:
# 서 있는 상태입니다.

# %% [markdown]
# # 위에 2개 합친것

# %%
from ultralytics import YOLO
import cv2

import numpy as np

from ultralytics.utils import ASSETS
from ultralytics.models.yolo.pose import PosePredictor







def calculate_angle(joint1, joint2, joint3): 
    # 어깨 골반 무릎 순서
    # 하지만 사실 점 3개를 해도 된다
    # 5,6 어깨
    # 11, 12 골반
    # 13, 14 무릎
    

    vector1 = np.squeeze(np.array(joint1.cpu())) - np.squeeze(np.array(joint2.cpu()))
    vector2 = np.squeeze(np.array(joint3.cpu())) - np.squeeze(np.array(joint2.cpu()))

    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)

    cosine_theta = dot_product / (magnitude1 * magnitude2)
    angle = np.arccos(np.clip(cosine_theta, -1.0, 1.0))

    return np.degrees(angle)


# # 어깨, 골반, 무릎으로 이루어진 각을 계산
# angle = calculate_angle(shoulder, pelvis, knee)

# # 각이 특정 값보다 작으면 앉은 상태로 간주
# threshold_angle = 90  # 예시값. 실제로는 실험을 통해 적절한 값을 찾아야 합니다.

# if angle < threshold_angle:
#     print("앉은 상태입니다.")
# else:
#     print("서 있는 상태입니다.")






# model = YOLO("yolo8s.pt")
model = YOLO("yolov8n-pose.pt")

cap = cv2.VideoCapture(0)
# cap = cv2.VideoCapture("/home/seokwon/Desktop/RNN_data/2023-11-06_16-06-45.avi") #  보는 시점 기준 정중앙에 서있음
# cap = cv2.VideoCapture("/home/seokwon/Desktop/RNN_data/2023-11-10_11-23-00.avi") # 보는 시점 기준 오른쪽에 서있음





while cap.isOpened() :
    ret, frame = cap.read()

    if ret :
        results = model(frame)
        for result in results:
            for keypoints in result.keypoints:
                try:
                    xyn = keypoints.xyn
                    # print("Keypoints [5] :", xyn[5])
                    # print("Keypoints [11] :", xyn[11])
                    # print("Keypoints [13] :", xyn[13])
                    if xyn.size == 0 :
                        print("fail")
                        continue


                    selected_keypoints = xyn[0, [5, 11, 13], :]
                    shoulder = xyn[0, [5], :]
                    hip = xyn[0, [11], :]
                    knee = xyn[0, [13], :]
                    print("Keypoints 어깨, 골반, 무릎:", selected_keypoints)

                    angle = calculate_angle(shoulder, hip, knee)


                    # 각이 특정 값보다 작으면 앉은 상태로 간주
                    threshold_angle = 120  # 예시값. 실제로는 실험을 통해 적절한 값을 찾아야 합니다.

                    if angle < threshold_angle:
                        print("앉은 상태입니다.")
                    else:
                        print("서 있는 상태입니다.")

                except IndexError as e:
                    print(f"IndexError: {e}")
                    continue

        cv2.imshow("Results", results[0].plot()) 

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.6ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.7ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.2ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 2.0ms preprocess, 4.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.4ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.8ms preprocess, 5.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.4ms preprocess, 4.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# Speed: 3.1ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.8ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 4.3ms
# Speed: 1.5ms preprocess, 4.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.8ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.7ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.8ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.5ms preprocess, 4.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.8ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.2ms preprocess, 7.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.9ms
# Speed: 1.3ms preprocess, 11.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 2.7ms preprocess, 5.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.4ms
# Speed: 1.1ms preprocess, 4.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 4.0ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 3.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.9ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 0.9ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.9ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.7ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 19.5ms
# Speed: 6.0ms preprocess, 19.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.9ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 3.1ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 2.7ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.2ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.4ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.0ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.8ms preprocess, 5.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.5ms
# Speed: 2.2ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.2ms
# Speed: 2.8ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.9ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.8ms
# Speed: 1.7ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.7ms
# Speed: 2.2ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 2.0ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.0ms
# Speed: 1.9ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.2ms
# Speed: 3.0ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.7ms
# Speed: 2.1ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 6.7ms
# Speed: 1.2ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 3.3ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# 0: 480x640 (no detections), 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 4.6ms
# Speed: 1.5ms preprocess, 4.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
# IndexError: index is out of bounds for dimension with size 0
